# %% [markdown]
# # Valid Anagram

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# # Test 1

# %%
task.isAnagram("anagram", "nagaram")
# Out:
# True

# %% [markdown]
# # Test 2

# %%
task.isAnagram("rat", "car")
# Out:
# False
