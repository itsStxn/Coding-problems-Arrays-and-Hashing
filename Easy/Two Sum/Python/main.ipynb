# %% [markdown]
# # Two Sum

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.twoSum(nums = [2,7,11,15], target = 9)

# %% [markdown]
# ## Test 2

# %% [markdown]
# ## Test 3
