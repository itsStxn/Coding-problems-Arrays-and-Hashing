# %% [markdown]
# # Two Sum

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.twoSum(nums = [2,7,11,15], target = 9)
# Out:
# [0, 1]

# %% [markdown]
# ## Test 2

# %%
task.twoSum(nums = [3,2,4], target = 6)
# Out:
# [1, 2]

# %% [markdown]
# ## Test 3

# %%
task.twoSum(nums = [3,3], target = 6)
# Out:
# [0, 1]
