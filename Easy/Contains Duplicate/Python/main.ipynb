# %% [markdown]
# # Contains Duplicate

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
nums = [1,2,3,1]
task.containsDuplicate(nums)
# Out:
# True

# %% [markdown]
# ## Test 2

# %%
nums = [1,2,3,4]
task.containsDuplicate(nums)
# Out:
# False

# %% [markdown]
# ## Test 3

# %%
nums = [1,1,1,3,3,4,3,2,4,2]
task.containsDuplicate(nums)
# Out:
# True
