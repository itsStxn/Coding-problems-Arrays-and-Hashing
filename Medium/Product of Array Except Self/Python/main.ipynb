# %% [markdown]
# # Product of Array Except Self

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.productExceptSelf(nums = [1,2,3,4])
# Out:
# [24, 12, 8, 6]

# %% [markdown]
# ## Test 2

# %%
task.productExceptSelf(nums = [-1,1,0,-3,3])
# Out:
# [0, 0, 9, 0, 0]
