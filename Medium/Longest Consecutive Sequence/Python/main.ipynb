# %% [markdown]
# # Longest Consecutive Sequence

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.longestConsecutive(nums = [100,4,200,1,3,2])

# %% [markdown]
# ## Test 2

# %%
task.longestConsecutive(nums = [0,3,7,2,5,8,4,6,0,1])

# %% [markdown]
# ## Test 3

# %%
task.longestConsecutive(nums = [0,3,7,2,5,8,4,6,0,1])
