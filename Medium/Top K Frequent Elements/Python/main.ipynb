# %% [markdown]
# # Top K Frequent Elements

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.topKFrequent(nums = [5,3,1,1,1,3,73,1], k = 2)
# Out:
# [1, 3, 5, 73]

# %% [markdown]
# ## Test 2

# %%
task.topKFrequent(nums = [1], k = 1)
# Out:
# [1]

# %% [markdown]
# ## Test 3

# %%
task.topKFrequent(nums = [1,2,1,2,1,2,3,1,3,2], k = 2)
# Out:
# [1, 2, 3]
