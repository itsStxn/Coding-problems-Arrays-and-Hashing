# %% [markdown]
# # String Encode and Decode

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
encoded = task.encode(strs = ["neet","code","love","you"])
encoded
# Out:
# '4:neet4:code4:love3:you'

# %%
task.decode(s = encoded)
# Out:
# ['neet', 'code', 'love', 'you']

# %% [markdown]
# ## Test 2

# %%
encoded = task.encode(strs = ["we","say",":","yes"])
encoded
# Out:
# '2:we3:say1::3:yes'

# %%
task.decode(s = encoded)
# Out:
# ['we', 'say', ':', 'yes']
