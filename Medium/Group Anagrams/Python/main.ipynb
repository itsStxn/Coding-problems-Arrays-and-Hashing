# %% [markdown]
# # Group Anagrams

# %%
import importlib
import solution as _

importlib.reload(_)
task = _.Solution()

# %% [markdown]
# ## Test 1

# %%
task.groupAnagrams(strs = ["eat","tea","tan","ate","nat","bat"])
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %% [markdown]
# ## Test 2

# %%
task.groupAnagrams(strs = [""])
# Out:
# [['']]

# %% [markdown]
# ## Test 3

# %%
task.groupAnagrams(strs = ["a"])
# Out:
# [['a']]
